# %%
import matplotlib.pyplot as plt
import numpy as np
from neurolib.models.multimodel import MultiModel
from neurolib.models.multimodel.builder import HopfNetwork
from neurolib.utils.functions import getPowerSpectrum
from neurolib.utils.stimulus import ZeroInput

from hopf_cfc_network import SlowFastHopfNetwork

plt.style.use("seaborn")

# w instrinsic
# 0.003 ~ 0.5Hz
# 0.005 ~ 0.8Hz
# 0.01 ~ 2Hz
# 0.05 ~ 8Hz
# 0.06 ~ 10Hz
# 0.08 ~ 12Hz
# 0.1 ~ 17Hz
# 0.2 ~ 32Hz
# 0.3 ~ 50Hz

# %%
DURATION = 20.0 * 1000  # ms
DT = 0.1  # ms

def simulate(slow_to_fast_conn=0.05):
    model = MultiModel(
        SlowFastHopfNetwork(
            number_of_slow_fast_units=1,
            slow_to_fast_connection=slow_to_fast_conn,
            fast_to_slow_connection=0.0,
        )
    )

    model.params["duration"] = 20.0 * 1000
    model.params["sampling_dt"] = DT
    model.params["dt"] = DT
    
    model.run()
    
    return model

# %%
for conn in np.around(np.linspace(0, 0.6, 11), 3):
    model = simulate(conn)
    _, axs = plt.subplots(nrows=2, ncols=2, sharex="col", figsize=(20, 10))

    axs[0, 0].plot(model.t, model.x.T[:, 0])
    axs[0, 0].set_ylabel("Slow activity")
    axs[1, 0].plot(model.t, model.x.T[:, 1], color="C1")
    axs[1, 0].set_ylabel("Fast activity")
    axs[1, 0].set_xlabel("time [s]")
    freq, pow = getPowerSpectrum(model.x.T[:, 0], dt=0.1, maxfr=40, spectrum_windowsize=1)
    axs[0, 1].plot(freq, pow)
    axs[0, 1].set_ylabel("Slow spectrum")
    freq, pow = getPowerSpectrum(model.x.T[:, 1], dt=0.1, maxfr=40, spectrum_windowsize=1)
    axs[1, 1].plot(freq, pow, color="C1")
    axs[1, 1].set_ylabel("Fast spectrum")
    axs[1, 1].set_xlabel("Frequency [Hz]")

    axs[0, 0].set_xlim([0, 0.5])
    plt.suptitle(f"slow -> fast connection: {conn}")
    plt.show()
# Out:
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# Using default integration parameters.
#   0%|                                                                                                                                                                            | 0/200000 [00:00<?, ?it/s]/Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:792: UserWarning: The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.
#   warn("The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.")
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200000/200000 [00:00<00:00, 306427.12it/s]
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# Using default integration parameters.
#   0%|                                                                                                                                                                            | 0/200000 [00:00<?, ?it/s]/Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:792: UserWarning: The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.
#   warn("The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.")
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200000/200000 [00:00<00:00, 303824.44it/s]
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# Using default integration parameters.
#   0%|                                                                                                                                                                            | 0/200000 [00:00<?, ?it/s]/Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:792: UserWarning: The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.
#   warn("The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.")
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200000/200000 [00:00<00:00, 310135.65it/s]
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# Using default integration parameters.
#   0%|                                                                                                                                                                            | 0/200000 [00:00<?, ?it/s]/Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:792: UserWarning: The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.
#   warn("The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.")
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200000/200000 [00:00<00:00, 297371.25it/s]
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# Using default integration parameters.
#   0%|                                                                                                                                                                            | 0/200000 [00:00<?, ?it/s]/Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:792: UserWarning: The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.
#   warn("The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.")
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200000/200000 [00:00<00:00, 311180.50it/s]
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# Using default integration parameters.
#   0%|                                                                                                                                                                            | 0/200000 [00:00<?, ?it/s]/Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:792: UserWarning: The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.
#   warn("The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.")
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200000/200000 [00:00<00:00, 314638.01it/s]
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# Using default integration parameters.
#   0%|                                                                                                                                                                            | 0/200000 [00:00<?, ?it/s]/Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:792: UserWarning: The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.
#   warn("The target time is smaller than the current time. No integration step will happen. The returned state will be extrapolated from the interpolating Hermite polynomial for the last integration step. You may see this because you try to integrate backwards in time, in which case you did something wrong. You may see this just because your sampling step is small, in which case there is no need to worry.")
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200000/200000 [00:00<00:00, 323131.54it/s]
# /Users/nikola/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py:1492: UserWarning: Your input past does not begin at t=0 but at t=0.1. Values before the beginning of the past will be extrapolated. You very likely do not want this.
#   warn(f"Your input past does not begin at t=0 but at t={input[0].time}. Values before the beginning of the past will be extrapolated. You very likely do not want this.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/8l/kg7qz2vn3jn9_bzjm1p_pgq40000gn/T/ipykernel_49399/3776646384.py in <module>
#       1 for conn in np.linspace(0, 1, 11):
# ----> 2     model = simulate(conn)
#       3     _, axs = plt.subplots(nrows=2, ncols=2, sharex="col", figsize=(20, 10))
#       4
#       5     axs[0, 0].plot(model.t, model.x.T[:, 0])
#
# /var/folders/8l/kg7qz2vn3jn9_bzjm1p_pgq40000gn/T/ipykernel_49399/2075486900.py in simulate(slow_to_fast_conn)
#      15     model.params["dt"] = DT
#      16
# ---> 17     model.run()
#      18
#      19     return model
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/neurolib/models/multimodel/model.py in run(self, chunkwise, chunksize, bold, append, append_outputs, continue_run, noise_input)
#     147
#     148         if chunkwise is False:
# --> 149             self.integrate(append_outputs=append, simulate_bold=bold, noise_input=noise_input)
#     150             if continue_run:
#     151                 self.setInitialValuesToLastState()
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/neurolib/models/multimodel/model.py in integrate(self, append_outputs, simulate_bold, noise_input)
#     203             noise_input=noise_input,
#     204             backend=self.params["backend"],
# --> 205             return_xarray=True,
#     206         )
#     207         self.storeOutputsAndStates(result, append=append_outputs)
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/neurolib/models/multimodel/builder/base/backend.py in decorator(*args, **kwargs)
#      51     def decorator(*args, **kwargs):
#      52         time_start = time.time()
# ---> 53         result = method(*args, **kwargs)
#      54         logging.info(f"`{method.__name__}` call took {time.time() - time_start:.2f} s")
#      55         return result
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/neurolib/models/multimodel/builder/base/backend.py in run(self, duration, dt, noise_input, backend, return_xarray, **kwargs)
#     596             symbol_params=self.symbol_params,
#     597             float_params=self.float_params,
# --> 598             **kwargs,
#     599         )
#     600         logging.info("Integration done.")
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/neurolib/models/multimodel/builder/base/backend.py in run(self, duration, dt, noise_input, **kwargs)
#     470         logging.info("Setting past of the state vector...")
#     471         if self.initial_state.ndim == 1:
# --> 472             self._set_constant_past(self.initial_state)
#     473         elif self.initial_state.shape[1] == 1:
#     474             self._set_constant_past(self.initial_state, squeeze=True)
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/neurolib/models/multimodel/builder/base/backend.py in _set_constant_past(self, past_state, squeeze)
#     409         else:
#     410             self.dde_system.constant_past(past_state)
# --> 411         self.dde_system.adjust_diff()
#     412
#     413     def _set_past_from_vector(self, past_state, dt):
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py in adjust_diff(self, shift_ratio)
#     837                         The minima or maxima, respectively, of each component during the jump interval. See the documentation of `jump` on why you may want these.
#     838 		"""
# --> 839                 self._initiate()
#     840                 past = self.get_state()
#     841                 width = shift_ratio*(past[-1][0]-past[-2][0])
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py in _initiate(self)
#     547
#     548                 if self.DDE is None:
# --> 549                         assert len(self.past)>1, "You need to add at least two past points first. Usually this means that you did not set an initial past at all."
#     550
#     551                         if self.compile_attempt:
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/jitcdde/_jitcdde.py in past(self)
#    1537                         if self.regular_past[-1].time != 0:
#    1538                                 raise ValueError("For jitcdde_input, the initial past must end at t=0.")
# -> 1539                         self._past = chspy.join(self.regular_past,self.input_past)
#    1540                 return self._past
#    1541
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/chspy/_chspy.py in join(*splines)
#     854 	"""
#     855         splines = [spline.copy() for spline in splines]
# --> 856         match_anchors(*splines)
#     857         positions = np.cumsum([0,*(spline.n for spline in splines)])
#     858         n = positions[-1]
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/chspy/_chspy.py in match_anchors(*splines)
#     843         for times,spline in zip(timess,splines):
#     844                 for time in all_times-times:
# --> 845                         spline.interpolate_anchor(time)
#     846
#     847         # from itertools import combinations
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/chspy/_chspy.py in interpolate_anchor(self, time)
#     768                         value =     interpolate_vec(time,anchors)
#     769                         diff = interpolate_diff_vec(time,anchors)
# --> 770                         self.insert( i, (time,value,diff) )
#     771
#     772         def truncate(self,time):
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/chspy/_chspy.py in insert(self, key, item)
#     369
#     370         def insert(self,key,item):
# --> 371                 anchor = self.prepare_anchor(item)
#     372 		if (
#     373                                         (key!= 0 and key!=-len(self) and self[key-1].time>=anchor.time)
#
# ~/.virtualenvs/laura_cfc/lib/python3.7/site-packages/chspy/_chspy.py in prepare_anchor(self, x)
#     340
#     341         def prepare_anchor(self,x):
# --> 342                 x = x if isinstance(x,Anchor) else Anchor(*x)
#     343                 if x.state.shape != (self.n,):
#     344                         raise ValueError("State has wrong shape.")
#
# KeyboardInterrupt:
